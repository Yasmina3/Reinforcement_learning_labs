# %% [markdown]
# <a href="https://colab.research.google.com/github/Yasmina3/Reinforcement_learning_labs/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lab assignment 1: Introduction to Gym Library**

# %% [markdown]
# In this notebook, you will:
#
# - Undertand Reinforcement Learning (RL) and its core concepts.
# - Learn Gymnasium library for developing and benchmarking RL algorithms.
# - Install and explore Gymnasium environments on your system.
# - Run your first Gymnasium environment and interact with it using Python.
#
# Gymnasium (previously OpenAI Gym) is a library designed for developing and assessing reinforcement learning algorithms. It offers a set of standard environments to test RL models, such as classic control problems, Atari games, and robotics simulations.
#
# Key features of Gymnasium:
# - A standardized API for RL environments.
# - A wide range of built-in environments for testing algorithms.
# - Seamless integration with deep learning frameworks like TensorFlow and PyTorch.

# %% [markdown]
# ## **Section 1: Introduction to Reinforcement Learning**

# %% [markdown]
# Reinforcement Learning (RL) is a branch of machine learning where an agent learns to make decisions by interacting with an environment.
# The agent takes actions in an environment to maximize cumulative rewards. The key components of an RL system include:
#
# - **Agent**: The entity that learns and makes decisions.
# - **Environment**: The system in which the agent operates.
# - **State**: A representation of the environment at a given time.
# - **Action**: The set of possible moves the agent can take.
# - **Reward**: Feedback from the environment that guides the learning process.
#
# RL is used in many real-world applications, including robotics, game playing (like AlphaGo and Deep Q-Networks for Atari), and self-driving cars.

# %% [markdown]
# ## **Section 2: Gymnasium: The RL Benchmarking Library**

# %% [markdown]
# Gymnasium is a project that offers an API (application programming interface) for single-agent reinforcement learning environments, featuring implementations of popular environments such as cartpole, pendulum, mountain-car, mujoco, atari, and more. This Jupyter Notebook Lab will cover the basics of using Gymnasium, including its four main functions: `make()`, `Env.reset()`, `Env.step()`, and `Env.render()`.
#
# At the core of Gymnasium is the `Env` class, a high-level Python class that represents a Markov Decision Process (MDP) based on reinforcement learning theory (note: it is not a complete reconstruction and omits several MDP components). This class allows users to generate an initial state, transition to new states based on actions, and visualize the environment. In addition to Env, Wrapper classes are provided to help modify or augment the environment, particularly the agent's observations, rewards, and actions.
#
# Gymnasium offers an interface through which an agent interacts with the environment using the `step()` function and observes the resulting changes.

# %% [markdown]
# ## **Section 3: Install and explore Gym environments**

# %% [markdown]
# To install Gymnasium on a server or local machine, run:

# %%
# YOUR CODE HERE

# !pip install gymnasium
# !pip install pygame
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: pygame in /usr/local/lib/python3.11/dist-packages (2.6.1)

# %% [markdown]
# To install using a Notebook like Google’s Colab, use:

# %%
# YOUR CODE HERE

# %% [markdown]
# The command above installs Gymnasium along with the appropriate versions of its dependencies.
#
# Note: The Gymnasium RL library is officially supported on Linux and macOS, but it can also be installed on Windows. Follow this video for a step-by-step guide: [Install Gymnasium (OpenAI Gym) on Windows](https://www.youtube.com/watch?v=gMgj4pSHLww&list=PL58zEckBH8fCt_lYkmayZoR9XfDCW9hte)
#
# Once the installation is complete, verify the setup by importing the Gymnasium library and displaying its version using:

# %%
# YOUR CODE HERE

import gymnasium as gym
gym.__version__
# Out:
# '1.0.0'

# %% [markdown]
# ### **Exploring Gymnasium environments**
#
# As of November 2024, Gymnasium offers more than 60 built-in environments. To explore the available environments, you can use the `gym.envs.registry.all()` function, as demonstrated in the example below:

# %%
# List all registered environments
envs = gym.envs.registry.values()

# Print environment IDs
for env in envs:
    print(env.id)
# Out:
# CartPole-v0
# CartPole-v1
# MountainCar-v0
# MountainCarContinuous-v0
# Pendulum-v1
# Acrobot-v1
# phys2d/CartPole-v0
# phys2d/CartPole-v1
# phys2d/Pendulum-v0
# LunarLander-v3
# LunarLanderContinuous-v3
# BipedalWalker-v3
# BipedalWalkerHardcore-v3
# CarRacing-v3
# Blackjack-v1
# FrozenLake-v1
# FrozenLake8x8-v1
# CliffWalking-v0
# Taxi-v3
# tabular/Blackjack-v0
# tabular/CliffWalking-v0
# Reacher-v2
# Reacher-v4
# Reacher-v5
# Pusher-v2
# Pusher-v4
# Pusher-v5
# InvertedPendulum-v2
# InvertedPendulum-v4
# InvertedPendulum-v5
# InvertedDoublePendulum-v2
# InvertedDoublePendulum-v4
# InvertedDoublePendulum-v5
# HalfCheetah-v2
# HalfCheetah-v3
# HalfCheetah-v4
# HalfCheetah-v5
# Hopper-v2
# Hopper-v3
# Hopper-v4
# Hopper-v5
# Swimmer-v2
# Swimmer-v3
# Swimmer-v4
# Swimmer-v5
# Walker2d-v2
# Walker2d-v3
# Walker2d-v4
# Walker2d-v5
# Ant-v2
# Ant-v3
# Ant-v4
# Ant-v5
# Humanoid-v2
# Humanoid-v3
# Humanoid-v4
# Humanoid-v5
# HumanoidStandup-v2
# HumanoidStandup-v4
# HumanoidStandup-v5
# GymV21Environment-v0
# GymV26Environment-v0

# %% [markdown]
# You can also visit the [Gymnasium homepage](https://gymnasium.farama.org/), where the left-hand column contains links to all the available environments. Each environment’s webpage provides details, such as its actions, states, and other information.
#
# The environments are grouped into categories like Classic Control, Box2D, and more. Below are some common environments in each category:
#
# * **Classic Control**: These are standard environments commonly used in RL research, providing a balance of complexity and simplicity to test and benchmark RL algorithms. Some classic control environments in Gymnasium include:
#     * Acrobot
#     * Cart Pole
#     * Mountain Car Discrete
#     * Mountain Car Continuous
#     * Pendulum
#
# * **Box2D**: Box2D is a 2D physics engine used in games. Environments based on this engine include simple games like:
#     * Lunar Lander
#     * Car Racing
#
# * **ToyText**: These small and simple environments are typically used to debug RL algorithms. Many of them are based on grid world models or basic card games. Examples include:
#     * Blackjack
#     * Taxi
#     * Frozen Lake
#
# * **MuJoCo**: Multi-Joint dynamics with Contact (MuJoCo) is an open-source physics engine that simulates environments for applications such as robotics, biomechanics, and machine learning. MuJoCo environments in Gymnasium include:
#     * Ant
#     * Hopper
#     * Humanoid
#     * Swimmer
#     * And more
#
# In addition to the built-in environments, Gymnasium supports integration with numerous external environments using the same API.

# %% [markdown]
# ## **Section 4: First Gymnasium environment**

# %% [markdown]
# In this section, we will explore the `Taxi` environment from the OpenAI Gym Library. Taxi is one of the many environments available in OpenAI Gym, where the goal is to pick up passengers and drop them off at their destination in the fewest possible moves. In this lab, you will start by working with a taxi agent that takes random actions until it accomplishes its objective.

# %% [markdown]
# <p align="center">
#     <img src="images/taxi_env.png" align="center" width="300">
# <p>

# %% [markdown]
# **Description**
#
# There are four designated locations in the grid world indicated by R(ed), G(reen), Y(ellow), and B(lue). When the episode starts, the taxi starts off at a random square and the passenger is at a random location. The taxi drives to the passenger’s location, picks up the passenger, drives to the passenger’s destination (another one of the four specified locations), and then drops off the passenger. Once the passenger is dropped off, the episode ends.
#
# **Actions**
#
# There are 6 discrete deterministic actions:
#
# 0: move south
#
# 1: move north
#
# 2: move east
#
# 3: move west
#
# 4: pickup passenger
#
# 5: drop off passenger
#
# **Observations**
#
# There are 500 discrete states since there are 25 taxi positions, 5 possible locations of the passenger (including the case when the passenger is in the taxi), and 4 destination locations.
#
# Note that there are 400 states that can actually be reached during an episode. The missing states correspond to situations in which the passenger is at the same location as their destination, as this typically signals the end of an episode. Four additional states can be observed right after a successful episodes, when both the passenger and the taxi are at the destination. This gives a total of 404 reachable discrete states.
#
# Each state space is represented by the tuple: (taxi_row, taxi_col, passenger_location, destination)
#
# An observation is an integer that encodes the corresponding state. The state tuple can then be decoded with the “decode” method.
#
# **Passenger locations**:
#
# 0: R(ed)
#
# 1: G(reen)
#
# 2: Y(ellow)
#
# 3: B(lue)
#
# 4: in taxi
#
# **Destinations**:
#
# 0: R(ed)
#
# 1: G(reen)
#
# 2: Y(ellow)
#
# 3: B(lue)
#
# For more information about the Taxi environement visit the [Gym documentation](https://www.gymlibrary.dev/environments/toy_text/taxi/).
#
# After installation, we can load the Taxi environment and display its appearance using the 'ansi' render mode:

# %%
# YOUR CODE HERE
env= gym.make("Taxi-v3", render_mode="ansi")
obs, info = env.reset()
print(env.render())
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %% [markdown]
# * The filled square represents the taxi, which is yellow without a passenger and green with a passenger.
# * The pipe ("|") represents a wall which the taxi cannot cross.
# * R, G, Y, B are the possible pickup and destination locations. The blue letter represents the current passenger pick-up location, and the purple letter is the current destination.
#
# Now, visualize the Taxi environment using the 'human' render mode:

# %%
import matplotlib.pyplot as plt

# Create the environment with 'rgb_array' render mode
env = gym.make("Taxi-v3", render_mode="rgb_array")

# Reset the environment
obs, info = env.reset()

# Render the environment as an image
img = env.render()

# Display the image using Matplotlib
plt.imshow(img)
plt.axis("off")
plt.show()

# Close the environment
env.close()

# %% [markdown]
# The core interface in Gym is `env`, which serves as the unified environment interface. The following `env` methods will be particularly useful:
#
# * **env.reset**: Resets the environment and returns a random initial state.
# * **env.step(action)**: Advances the environment by one timestep. It returns:
#     * **observation**: The current state of the environment.
#     * **reward**: Indicates whether the action was beneficial or not.
#     * **done**: Signals whether the agent has successfully completed a task (e.g., picked up and dropped off a passenger), marking the end of one episode.
#     * **info**: Provides additional information, such as performance and latency, for debugging.
# * **env.render**: Renders a single frame of the environment, useful for visualization.
#
# **Note**: We use `.env` at the end of `make` to prevent training from stopping after 200 iterations, which is the default limit in the latest version of Gym (reference).

# %% [markdown]
# ### **The Taxi Environment Problem**
#
# Let’s explore the environment in more detail. Reset the Taxi environment, render its initial state, and display the action and state space in OpenAI Gym.

# %%
# YOUR CODE HERE

print("Action Space {}".format(env.action_space))
print("State Space {}".format(env.observation_space))
# Out:
# Action Space Discrete(6)
# State Space Discrete(500)

# %% [markdown]
# Based on the printed output, we can confirm that the Action Space has 6 possible actions, and the State Space consists of 500 unique states. Each state is uniquely identified by assigning a number to every possible state, and the agent selects an action from 0 to 5, as described earlier.
#
# The 500 states represent a combination of the taxi's location, the passenger's location, and the destination.
#
# Reinforcement learning works by mapping states to optimal actions through exploration. The agent interacts with the environment, takes actions, and learns based on the rewards assigned by the environment.
#
# The best action for each state is the one that maximizes the cumulative long-term reward.

# %% [markdown]
# ### **Illustration**
#
# Use the illustrated scenario from the image, encode its state, and pass it to the environment for rendering in Gym. The taxi is located at row 3, column 1, with the passenger at location 2 and the destination at location 0. By applying the state encoding method `env.encode` in the Taxi environment, we can achieve this as follows:

# %%
# Create the Taxi environment with 'ansi' render mode
env = gym.make("Taxi-v3", render_mode="ansi")

# Encode a specific state (taxi_row=3, taxi_col=1, passenger=2, destination=0)
state = env.unwrapped.encode(3, 1, 2, 0)  # Use env.unwrapped to access the raw encode function
print("State:", state)

# Set the environment state
env.unwrapped.s = state
env.reset()
# Render and print the environment
print(env.render())

# Close the environment
env.close()
# Out:
# State: 328
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %% [markdown]
# We are using our illustration's coordinates to generate a number corresponding to a state between 0 and 499, which turns out to be 328 for our illustration's state.
#
# Using this encoded number, we can manually set the environment’s state with `env.env.s`. You can experiment with different numbers and observe how the taxi, passenger, and destination change positions.

# %% [markdown]
# ### **The Reward Table**
#
# When the Taxi environment is initialized, a reward table called `P` is automatically generated. This table can be viewed as a matrix where the rows represent the number of states and the columns represent the number of actions, forming a **states × actions** matrix.
#
# Since every state is included in this matrix, we can examine the default reward values assigned to the state in our illustration.

# %%
# YOUR CODE HERE
for action in range(env.action_space.n):
    print(f"Action {action}: {env.unwrapped.P[state][action]}")
# Out:
# Action 0: [(1.0, 428, -1, False)]
# Action 1: [(1.0, 228, -1, False)]
# Action 2: [(1.0, 348, -1, False)]
# Action 3: [(1.0, 328, -1, False)]
# Action 4: [(1.0, 328, -10, False)]
# Action 5: [(1.0, 328, -10, False)]

# %% [markdown]
# The dictionary in the reward table follows the structure `{action: [(probability, next_state, reward, done)]}`.
#
# Key points to note:
#
# - The numbers 0-5 correspond to the possible actions the taxi can take in the current state: **south, north, east, west, pickup, and dropoff**.
# - In this environment, the probability value is always **1.0**.
# - `next_state` represents the state the agent will transition to after taking the specified action.
# - Movement actions (south, north, east, west) result in a **-1 reward**, while pickup and dropoff actions give a **-10 reward** in this particular state. However, if the taxi has a passenger and is at the correct drop-off location, the dropoff action (5) would yield a **+20 reward**.
# - `done` indicates whether the episode has ended, meaning the passenger has been successfully dropped off at the correct location.
#
# **Note:** If the agent chooses action **2 (east)** in this state, it will attempt to move into a wall. However, the environment prevents the taxi from crossing walls, so it will remain in the same position while continuously receiving **-1 penalties**, negatively impacting its long-term reward.

# %% [markdown]
# ### **Random Agent**
#
# We will begin by implementing an agent that takes random actions without any learning. This will serve as our baseline.
#
# The first step is to provide our agent with an initial state of the environment. A state represents how the agent perceives its surroundings. In the Taxi environment, a state includes the current positions of the taxi, the passenger, and the designated pick-up and drop-off locations. Below are examples of three different states in the Taxi environment:

# %% [markdown]
# <p align="center">
#     <img src="images/taxi-states.png" align="center" width=450>
# <p>

# %% [markdown]
# **Note:**
# - **Yellow** represents the taxi.
# - **Blue letters** indicate pickup locations.
# - **Purple letters** mark drop-off destinations.
#
# Next, we will run a loop to simulate the game. In each iteration, our agent will:
#
# 1. Select a random action from the action space:
#    - **0** → Move south
#    - **1** → Move north
#    - **2** → Move east
#    - **3** → Move west
#    - **4** → Pick up the passenger
#    - **5** → Drop off the passenger
# 2. Receive the updated state after performing the action.
#
# Below is the script for our random agent:

# %%
import gymnasium as gym
import time

# Create the Taxi environment
env = gym.make("Taxi-v3", render_mode="ansi")

# Reset the environment
state, info = env.reset()

# Number of steps the agent will take
num_steps = 1000

# Initialize accumulated reward variable
total_reward = 0

print("Initial State:")
print(env.render())  # Print the initial state

for step in range(num_steps):
    action = env.action_space.sample()  # Choose a random action
    next_state, reward, done, truncated, info = env.step(action)  # Take action

    # Accumulate the reward
    total_reward += reward

    print(f"\nStep {step + 1}:")
    print(f"Action Taken: {action}")
    print(f"Reward Received: {reward}")
    print(f"Accumulated Reward: {total_reward}")
    print(env.render())  # Print updated state

    if done:  # If episode ends (passenger dropped off correctly)
        print("Episode finished!\n")
        break  # Stop the loop

# Close the environment
env.close()

# Final accumulated reward
print(f"\nFinal Accumulated Reward: {total_reward}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -507
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 121:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -508
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 122:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -509
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 123:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -510
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 124:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -520
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 125:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -530
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 126:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -531
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 127:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -541
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 128:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -542
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 129:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -552
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 130:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -553
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 131:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -554
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 132:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -555
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 133:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -556
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 134:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -557
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 135:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -567
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 136:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -568
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 137:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -569
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 138:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -570
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 139:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -580
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 140:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -581
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 141:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -582
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 142:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -583
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 143:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -584
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 144:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -585
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 145:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -586
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 146:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -587
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 147:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -597
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 148:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -598
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 149:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -608
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 150:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -609
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 151:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -610
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 152:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -611
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 153:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -621
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 154:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -622
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 155:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -623
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 156:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -624
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 157:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -634
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 158:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -635
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 159:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -645
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 160:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -646
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 161:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -647
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 162:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -648
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 163:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -649
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 164:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -650
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 165:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -651
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 166:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -661
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 167:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -662
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 168:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -663
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 169:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -673
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 170:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -674
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 171:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -684
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 172:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -685
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 173:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -686
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 174:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -687
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 175:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -697
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 176:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -698
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 177:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -699
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 178:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -709
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 179:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -710
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 180:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -720
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 181:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -721
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 182:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -731
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 183:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -732
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 184:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -742
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 185:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -752
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 186:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -762
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 187:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -763
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 188:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -764
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 189:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -774
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 190:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -784
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 191:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -785
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 192:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -786
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 193:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -787
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 194:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -788
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 195:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -789
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 196:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -799
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 197:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -800
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 198:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -801
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 199:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -802
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 200:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -803
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 201:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -813
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 202:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -823
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 203:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -833
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 204:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -834
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 205:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -835
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 206:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -845
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 207:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -846
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 208:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -847
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 209:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -857
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 210:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -858
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 211:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -859
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 212:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -860
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 213:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -870
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 214:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -880
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 215:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -890
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 216:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -891
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 217:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -892
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 218:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -902
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 219:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -903
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 220:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -904
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 221:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -905
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 222:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -906
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 223:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -907
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 224:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -917
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 225:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -927
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 226:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -928
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 227:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -929
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 228:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -930
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 229:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -931
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 230:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -941
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 231:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -951
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 232:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -952
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 233:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -953
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 234:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -963
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 235:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -964
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 236:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -965
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 237:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -966
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 238:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -967
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 239:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -968
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 240:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -969
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 241:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -970
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 242:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -971
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 243:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -972
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 244:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -973
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 245:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -983
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 246:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -993
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 247:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1003
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 248:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1013
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 249:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1023
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 250:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1024
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 251:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1025
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 252:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1026
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 253:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1036
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 254:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1037
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 255:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1038
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 256:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1039
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 257:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1040
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 258:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1041
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 259:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1042
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 260:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1043
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 261:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1044
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 262:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1054
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 263:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1055
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 264:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1065
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 265:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1075
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 266:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1076
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 267:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1077
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 268:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1078
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 269:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1079
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 270:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1080
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 271:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1081
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 272:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1082
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 273:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1083
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 274:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1093
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 275:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1103
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 276:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1104
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 277:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1114
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 278:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1115
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 279:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1116
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 280:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1117
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 281:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1118
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 282:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1128
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 283:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1138
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 284:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1148
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 285:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1149
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 286:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1150
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 287:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1160
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 288:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1161
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 289:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1171
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 290:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1172
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 291:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1173
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 292:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1183
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 293:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1184
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 294:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1194
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 295:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1195
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 296:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1196
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 297:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1197
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 298:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1198
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 299:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1199
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 300:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1209
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 301:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1210
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 302:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1211
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 303:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1212
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 304:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1222
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 305:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1232
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 306:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1233
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 307:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1234
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 308:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1235
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 309:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1245
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 310:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1255
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 311:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1256
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 312:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1257
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 313:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1267
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 314:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1277
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 315:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1278
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 316:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1288
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 317:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1298
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 318:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1299
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 319:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1309
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 320:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1310
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 321:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1311
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 322:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1321
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 323:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1322
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 324:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1323
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 325:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1333
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 326:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1334
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 327:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1335
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 328:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1345
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 329:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1346
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 330:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1347
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 331:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1357
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 332:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1367
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 333:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1368
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 334:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1369
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 335:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1370
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 336:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1371
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 337:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1372
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 338:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1373
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 339:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1374
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 340:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1375
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 341:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1376
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 342:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1377
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 343:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1378
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 344:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1379
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 345:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1389
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 346:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1390
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 347:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1400
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 348:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1410
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 349:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1411
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 350:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1412
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 351:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1422
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 352:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1423
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 353:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1424
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 354:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1434
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 355:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1444
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 356:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1445
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 357:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1446
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 358:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1456
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 359:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1457
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 360:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1458
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 361:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1459
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 362:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1460
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 363:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1470
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 364:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1471
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 365:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1481
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 366:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1482
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 367:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1483
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 368:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1493
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 369:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1494
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 370:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1495
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 371:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1496
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 372:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1497
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 373:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1498
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 374:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1499
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 375:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1509
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 376:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1510
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 377:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1511
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 378:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1512
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 379:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1522
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 380:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1523
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 381:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1533
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 382:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1534
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 383:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1535
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 384:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1536
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 385:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1537
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 386:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1547
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 387:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1548
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 388:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1549
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 389:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1550
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 390:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1551
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 391:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1561
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 392:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1562
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 393:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1563
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 394:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1564
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 395:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1565
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 396:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1566
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 397:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1567
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 398:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1577
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 399:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1578
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 400:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1588
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 401:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1589
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 402:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1590
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 403:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1591
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 404:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1601
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 405:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1611
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 406:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1612
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 407:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1613
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 408:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1614
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 409:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1615
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 410:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1625
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 411:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1635
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 412:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1636
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 413:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1637
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 414:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1647
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 415:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1648
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 416:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1658
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 417:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1668
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 418:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1669
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 419:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1670
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 420:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1671
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 421:
# Action Taken: 4
# Reward Received: -1
# Accumulated Reward: -1672
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 422:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1682
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 423:
# Action Taken: 5
# Reward Received: -1
# Accumulated Reward: -1683
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 424:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1684
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 425:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1685
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 426:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1686
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 427:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1696
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 428:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1697
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 429:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1698
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 430:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1708
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 431:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1709
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 432:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1710
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 433:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1711
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 434:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1712
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 435:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1713
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 436:
# Action Taken: 4
# Reward Received: -1
# Accumulated Reward: -1714
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 437:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1715
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 438:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1716
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 439:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1717
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 440:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1727
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 441:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1737
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 442:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1738
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 443:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1739
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 444:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1749
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 445:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1750
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 446:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1751
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# |_| : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 447:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1752
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# |_| : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 448:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1753
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# |_| : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 449:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1754
# +---------+
# |R: | : :G|
# | : | : : |
# |_: : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 450:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1755
# +---------+
# |R: | : :G|
# | : | : : |
# |_: : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 451:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1756
# +---------+
# |R: | : :G|
# |_: | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 452:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1757
# +---------+
# |R: | : :G|
# | :_| : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 453:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1758
# +---------+
# |R:_| : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 454:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1759
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 455:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1769
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 456:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1770
# +---------+
# |R:_| : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 457:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1771
# +---------+
# |R:_| : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 458:
# Action Taken: 0
# Reward Received: -1
# Accumulated Reward: -1772
# +---------+
# |R: | : :G|
# | :_| : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
#
# Step 459:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1773
# +---------+
# |R: | : :G|
# |_: | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 460:
# Action Taken: 5
# Reward Received: -10
# Accumulated Reward: -1783
# +---------+
# |R: | : :G|
# |_: | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
#
# Step 461:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1793
# +---------+
# |R: | : :G|
# |_: | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 462:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1794
# +---------+
# |R: | : :G|
# | :_| : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 463:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1795
# +---------+
# |R: | : :G|
# | :_| : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 464:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1805
# +---------+
# |R: | : :G|
# | :_| : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 465:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1806
# +---------+
# |R: | : :G|
# |_: | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 466:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1816
# +---------+
# |R: | : :G|
# |_: | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 467:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1817
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 468:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1827
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 469:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1828
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 470:
# Action Taken: 2
# Reward Received: -1
# Accumulated Reward: -1829
# +---------+
# |R:_| : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
#
# Step 471:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1830
# +---------+
# |R:_| : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 472:
# Action Taken: 4
# Reward Received: -10
# Accumulated Reward: -1840
# +---------+
# |R:_| : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
#
# Step 473:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1841
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 474:
# Action Taken: 3
# Reward Received: -1
# Accumulated Reward: -1842
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
#
# Step 475:
# Action Taken: 1
# Reward Received: -1
# Accumulated Reward: -1843
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
#
# Step 476:
# Action Taken: 5
# Reward Received: 20
# Accumulated Reward: -1823
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Episode finished!
#
#
# Final Accumulated Reward: -1823

# %% [markdown]
# You can run this script to observe your agent taking random actions. This serves as a great introduction to the OpenAI Gym toolkit and helps you understand how the environment works.
#
# To visualize the animation of your random agent's actions, execute the following code:

# %% [markdown]
# The results are not good. Our agent takes thousands of timesteps and makes numerous incorrect drop-offs, delivering just one passenger to the right destination.
#
# This happens because the agent is not learning from its past actions. We can run this process repeatedly, but it will never improve. The agent has no memory of which actions work best for each state, which is where Reinforcement Learning comes in.
#
# In the next labs, we will implement reinforcement learning algorithms that will allow our agent to learn from rewards and improve its performance over time.

# %% [markdown]
# ## **Section 5: Conclusion**

# %% [markdown]
# Great work! You have:
# - Undertand Reinforcement Learning (RL) and its core concepts.
# - Learn Gymnasium library for developing and benchmarking RL algorithms.
# - Install and explore Gymnasium environments on your system.
# - Run your first Gymnasium environment and interact with it using Python.
